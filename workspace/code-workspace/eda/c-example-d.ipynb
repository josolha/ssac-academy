# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# jobkorea 검색 결과 크롤링

resp = requests.get("http://www.jobkorea.co.kr/Search/?stext=데이터분석&tabType=recruit&Page_No=1")

# %%
print( resp.status_code )
print( resp.text[:200] )
# Out:
# 200
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=e

# %%
soup = BeautifulSoup(resp.text, 'html.parser')

# %%
# 채용정보 목록에서 채용정보 항목 가져오기
lis = soup.select('div.recruit-info li[data-gno]') # 선택자[attr-name] : attr-name 속성이 있는 요소, 선택자
# lis[0]

# %%
lis
# Out:
# []

# %%
rows = []
for li in lis:
    cname = li.select_one(".post-list-corp a").get_text().strip()
    title = li.select_one('.post-list-info a').get_text().strip()
    exp = li.select_one('.post-list-info p.option .exp').get_text().strip()
    edu = li.select_one('.post-list-info p.option .edu').get_text().strip()
    loc = li.select_one('.post-list-info p.option .loc.long').get_text().strip() # 두 개의 class 정보는 .class1.class2
    # print(cname, " / ", title, " / ", edu)
    rows.append([cname, title, exp, edu, loc])

# rows

# %%
# 페이징이 있는 웹사이트의 여러 페이지에서 데이터 수집

import time

keyword = '하둡'
page_no = 1

rows = []

while True:

    # print("processing page {0}".format(page_no))

    resp = requests.get("http://www.jobkorea.co.kr/Search/?stext={0}&tabType=recruit&Page_No={1}".format(keyword, page_no))

    soup = BeautifulSoup(resp.text, 'html.parser')
    
    lis = soup.select('div.recruit-info li[data-gno]')

    if lis == None or len(lis) == 0: # 마지막페이지 + 1인 조건
        print("end of data")
        break

    for li in lis:
        cname = li.select_one(".post-list-corp a").get_text().strip()
        title = li.select_one('.post-list-info a').get_text().strip()
        exp = li.select_one('.post-list-info p.option .exp').get_text().strip()
        edu = li.select_one('.post-list-info p.option .edu')
        edu = np.nan if edu == None else edu.get_text().strip()        
        loc = li.select_one('.post-list-info p.option .loc.long').get_text().strip()
        rows.append([cname, title, exp, edu, loc])

    page_no += 1 # page_no = page_no + 1

    time.sleep(1)
# Out:
# end of data

# %%
print( len(rows) )
rows[:10]
# Out:
# 238
# [['카카오페이', '[기술플랫폼실] 빅데이터, 하둡(Hadoop) 플랫폼 운영 엔지니어 영입', '경력', nan, '경기 성남시'],
#  ['누리꿈소프트㈜',
#   '[수도권,정규직] 하둡 플랫폼 구축 및 유지보수 인원 구인합니다.',
#   '경력3년↑',
#   '학력무관',
#   '서울 강남구'],
#  ['아이티아이즈',
#   'DB설치구성 엔지니어 / 퍼블릭 클라우드 운영자 / 하둡 설치엔지니어 모집',
#   '신입·경력2년↑',
#   '초대졸↑',
#   '서울 영등포구'],
#  ['엔에이치엔 주식회사', '[NHN] 2021년 (신입) 전문연구요원 모집', '신입', '석사↑', '경기 성남시'],
#  ['㈜유비케어', 'GC녹십자그룹 가족사 상반기 공개채용', '신입·경력', '초대졸↑', '서울 영등포구'],
#  ['롯데멤버스㈜',
#   '[롯데멤버스] 2021 상반기 경력채용 (제휴컨설팅 / 데이터분석 / 데이터거버넌스 / 디지털마케팅 / 정보보호 / 솔루션사업)',
#   '경력3년↑',
#   '초대졸↑',
#   '서울 중구'],
#  ['현대엠엔소프트㈜',
#   '신입/경력사원 공개채용(S/W개발,품질,기획/디자인,경영지원 부문)',
#   '신입·경력',
#   '대졸↑',
#   '서울 용산구'],
#  ['㈜그리드위즈', '각 부문 신입 및 경력직원 채용', '신입·경력2년↑', '학력무관', '경기 성남시'],
#  ['한국직업전문학교',
#   '[4차산업 IT과정 - 국비무료] 디지털컨버젼스 응용SW 개발 (JAVA,Python) 모집',
#   '신입·경력',
#   '학력무관',
#   '경기 전지역 외'],
#  ['아이비케이투자증권㈜', '2021년 IBK투자증권 경력사원 채용', '경력', '학력무관', '경기 전지역 외']]

# %%
pd.DataFrame(data=rows, columns=['cname', 'title', 'exp', 'edu', 'loc'])
# Out:
#             cname                                              title  \
# 0           카카오페이           [기술플랫폼실] 빅데이터, 하둡(Hadoop) 플랫폼 운영 엔지니어 영입
# 1         누리꿈소프트㈜               [수도권,정규직] 하둡 플랫폼 구축 및 유지보수 인원 구인합니다.
# 2          아이티아이즈          DB설치구성 엔지니어 / 퍼블릭 클라우드 운영자 / 하둡 설치엔지니어 모집
# 3      엔에이치엔 주식회사                         [NHN] 2021년 (신입) 전문연구요원 모집
# 4           ㈜유비케어                               GC녹십자그룹 가족사 상반기 공개채용
# ..            ...                                                ...
# 233           대기업  N 그룹 계열 클라우드 플랫폼 제공 IT 전문 대기업 부문별 경력직 채용(23개 포지션)
# 234          벤처기업                   [서울 성동] E-Commerce Data Engineer
# 235  중소기업(300명이하)                               클라우드 빅데이터플랫폼 상품개발 채용
# 236  중견기업(300명이상)                                  클라우드 빅데이터플랫폼 상품개발
# 237  중소기업(300명이하)                 Data 분석 엔지니어, Data 기획 (대리-차장급), 분당
#
#           exp   edu       loc
# 0          경력   NaN    경기 성남시
# 1       경력3년↑  학력무관    서울 강남구
# 2    신입·경력2년↑  초대졸↑   서울 영등포구
# 3          신입   석사↑    경기 성남시
# 4       신입·경력  초대졸↑   서울 영등포구
# ..        ...   ...       ...
# 233     경력3년↑   대졸↑    경기 성남시
# 234     경력1년↑   대졸↑    서울 성동구
# 235     경력3년↑  학력무관  경기 성남시 외
# 236     경력2년↑   대졸↑    경기 성남시
# 237     경력5년↑   대졸↑    경기 성남시
#
# [238 rows x 5 columns]

# %%
import pymysql # 데이터베이스 연동 모듈 준비

# %%
# 1. 연결하기
conn = pymysql.connect(host='localhost',
                       database='pydemodb',
                       user='root',
                       password='Pa$$w0rd',
                       charset='utf8')

# 2. 명령하기
with conn.cursor() as cursor:
    sql = """
        create table tbl_recruit(
            idx int primary key auto_increment,
            cname varchar(100) not null,
            title varchar(1000) not null,
            exp varchar(100) null,
            edu varchar(100) null,
            loc varchar(100) null
        )
    """
    cursor.execute(sql)

conn.close()

# %%
# 1. 연결하기
conn = pymysql.connect(host='localhost',
                       database='pydemodb',
                       user='root',
                       password='Pa$$w0rd',
                       charset='utf8')

# 2. 명령하기
with conn.cursor() as cursor:
    sql = """
        insert into tbl_recruit (cname, title, exp, edu, loc) 
        values (%s, %s, %s, %s, %s)
    """
    # for numbers in numbers_list:
    #     cursor.execute(sql, numbers)

    cursor.executemany(sql, rows)

    conn.commit()

conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-8-4edcfcb9b89b> in <module>
#      15     #     cursor.execute(sql, numbers)
#      16
# ---> 17     cursor.executemany(sql, rows)
#      18
#      19     conn.commit()
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     188             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     189                                          self.max_stmt_length,
# --> 190                                          self._get_db().encoding)
#     191
#     192         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     204         sql = bytearray(prefix)
#     205         args = iter(args)
# --> 206         v = values % escape(next(args), conn)
#     207         if isinstance(v, text_type):
#     208             if PY2:
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\cursors.py in _escape_args(self, args, conn)
#     113             if PY2:
#     114                 args = tuple(map(ensure_bytes, args))
# --> 115             return tuple(conn.literal(arg) for arg in args)
#     116         elif isinstance(args, dict):
#     117             if PY2:
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\cursors.py in <genexpr>(.0)
#     113             if PY2:
#     114                 args = tuple(map(ensure_bytes, args))
# --> 115             return tuple(conn.literal(arg) for arg in args)
#     116         elif isinstance(args, dict):
#     117             if PY2:
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\connections.py in literal(self, obj)
#     467         Non-standard, for internal use; do not use this in your applications.
#     468         """
# --> 469         return self.escape(obj, self.encoders)
#     470
#     471     def escape_string(self, s):
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\connections.py in escape(self, obj, mapping)
#     460                 ret = "_binary" + ret
#     461             return ret
# --> 462         return converters.escape_item(obj, self.charset, mapping=mapping)
#     463
#     464     def literal(self, obj):
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\converters.py in escape_item(val, charset, mapping)
#      25         val = encoder(val, charset, mapping)
#      26     else:
# ---> 27         val = encoder(val, mapping)
#      28     return val
#      29
#
# C:\ProgramData\Miniconda3\envs\ssac-one\lib\site-packages\pymysql\converters.py in escape_float(value, mapping)
#      57     s = repr(value)
#      58     if s in ('inf', 'nan'):
# ---> 59         raise ProgrammingError("%s can not be used with MySQL" % s)
#      60     if 'e' not in s:
#      61         s += 'e0'
#
# ProgrammingError: nan can not be used with MySQL
